# %%
import pandas as pd # type: ignore
from datetime import datetime # type: ignore
import numpy as np #type: ignore
from keras.models import Sequential # type: ignore
# from keras.layers import Dense, LSTM, Dropout # type: ignore
from keras.layers import Dense, Bidirectional, GRU, Dropout # type: ignore
from keras.optimizers import Adam # type: ignore
from matplotlib import pyplot as plt # type: ignore
from sklearn.preprocessing import MinMaxScaler # type: ignore
import seaborn as sns # type: ignore

# %%
df = pd.read_csv('datasets/dataset_PS.csv')
df = df.astype({'date': 'datetime64[ns]'})
# df.drop(columns=['irradiation', 'cloudiness', 'holiday', 'precipitation'], inplace=True)
df['shifted_consumption_168'] = df['consumption'].shift(168)
df['shifted_consumption_48'] = df['consumption'].shift(48)
df['hour'] = df['date'].dt.hour
df['weekDay'] = df['date'].dt.weekday
df = df.fillna(df.mean())
df.head()
# Out:
#                  date  consumption  temperature  precipitation  irradiation  \
# 0 2022-01-01 01:00:00       1018.0         -3.2            0.0          0.0
# 1 2022-01-01 02:00:00        975.0         -3.9            0.0          0.0
# 2 2022-01-01 03:00:00        944.0         -2.8            0.0          0.0
# 3 2022-01-01 04:00:00        936.0         -3.1            0.0          0.0
# 4 2022-01-01 05:00:00        952.0         -4.1            0.0          0.0
#
#    cloudiness  holiday  shifted_consumption_168  shifted_consumption_48  hour  \
# 0        37.0      1.0              1295.358621             1295.144189     1
# 1        37.0      1.0              1295.358621             1295.144189     2
# 2        37.0      1.0              1295.358621             1295.144189     3
# 3        37.0      1.0              1295.358621             1295.144189     4
# 4        37.0      1.0              1295.358621             1295.144189     5
#
#    weekDay
# 0        5
# 1        5
# 2        5
# 3        5
# 4        5

# %%
# remove last week of data
df = df.iloc[:-168]
df.tail()
# Out:
#                      date  consumption  temperature  precipitation  \
# 24447 2024-10-16 19:00:00       1627.0         11.9            0.0
# 24448 2024-10-16 20:00:00       1601.0         11.5            0.0
# 24449 2024-10-16 21:00:00       1452.0         11.2            0.0
# 24450 2024-10-16 22:00:00       1330.0         10.9            0.2
# 24451 2024-10-16 23:00:00       1228.0         10.7            0.4
#
#        irradiation  cloudiness  holiday  shifted_consumption_168  \
# 24447          0.0        97.0      0.0                   1608.0
# 24448          0.0        97.0      0.0                   1551.0
# 24449          0.0        97.0      0.0                   1445.0
# 24450          0.0        97.0      0.0                   1335.0
# 24451          0.0        97.0      0.0                   1199.0
#
#        shifted_consumption_48  hour  weekDay
# 24447                  1536.0    19        2
# 24448                  1497.0    20        2
# 24449                  1394.0    21        2
# 24450                  1288.0    22        2
# 24451                  1166.0    23        2

# %%
# extract dates from the dataframe
df_dates = list(df['date'])
print(df_dates[0:5])
# Out:
# [Timestamp('2022-01-01 01:00:00'), Timestamp('2022-01-01 02:00:00'), Timestamp('2022-01-01 03:00:00'), Timestamp('2022-01-01 04:00:00'), Timestamp('2022-01-01 05:00:00')]

# %%
# columns used from training dataset
cols = list(df)[1:3]
df_for_training = df[cols].astype(float)
df_for_training.head()
# Out:
#    consumption  temperature
# 0       1018.0         -3.2
# 1        975.0         -3.9
# 2        944.0         -2.8
# 3        936.0         -3.1
# 4        952.0         -4.1

# %%
df_for_training.iloc[:, 0].tail(168).plot.line()
df_for_training.iloc[:, 1:4].tail(168).plot.line()
# Out:
# <Axes: >

# %%
# scaling the training data
scaler = MinMaxScaler(feature_range=(0, 1))
scaler = scaler.fit(df_for_training)
df_for_training_scaled = scaler.transform(df_for_training)
df_for_training_scaled
# Out:
# array([[0.46890834, 0.23954373],
#        [0.4491018 , 0.22623574],
#        [0.43482266, 0.24714829],
#        ...,
#        [0.66881621, 0.51330798],
#        [0.61262091, 0.50760456],
#        [0.56563795, 0.50380228]])

# %%
# creating the trainX and trainY
trainX = []
trainY = []

n_future = 1 # number of hours we want to predict into the future
n_past = 168 # 168 hours, because of weekly variation

for i in range(n_past, len(df_for_training_scaled) - n_future + 1): # from 168 to the end without going out of bounds
	trainX.append(df_for_training_scaled[i - n_past:i, 0:df_for_training.shape[1]]) # from 168 to the end
	trainY.append(df_for_training_scaled[i + n_future - 1:i + n_future, 0]) # from 168 to the end

trainX, trainY = np.array(trainX), np.array(trainY)

print('trainX shape == {}.'.format(trainX.shape))
print('trainY shape == {}.'.format(trainY.shape))
# Out:
# trainX shape == (24284, 168, 2).
# trainY shape == (24284, 1).

# %%
# defining the model
model = Sequential()
model.add(Bidirectional(GRU(units=50, return_sequences=True), input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dropout(0.2))
model.add(Bidirectional(GRU(units=50)))
model.add(Dropout(0.2))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mse')

model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional_4 (Bidirectional) │ (None, 168, 100)       │        16,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 168, 100)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_5 (Bidirectional) │ (None, 100)            │        45,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 61,901 (241.80 KB)
#  Trainable params: 61,901 (241.80 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# fit model
history = model.fit(trainX, trainY, epochs=10, batch_size=64, validation_split=0.1, verbose=1)
# Out:
# Epoch 1/10
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 59s 152ms/step - loss: 0.0204 - val_loss: 0.0019
# Epoch 2/10
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 52s 152ms/step - loss: 0.0034 - val_loss: 0.0012
# Epoch 3/10
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 47s 139ms/step - loss: 0.0026 - val_loss: 9.9877e-04
# Epoch 4/10
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 46s 135ms/step - loss: 0.0021 - val_loss: 0.0010
# Epoch 5/10
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 46s 133ms/step - loss: 0.0019 - val_loss: 6.9438e-04
# Epoch 6/10
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 46s 133ms/step - loss: 0.0017 - val_loss: 6.1630e-04
# Epoch 7/10
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 39s 113ms/step - loss: 0.0015 - val_loss: 6.1095e-04
# Epoch 8/10
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 38s 112ms/step - loss: 0.0014 - val_loss: 6.3368e-04
# Epoch 9/10
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 39s 114ms/step - loss: 0.0013 - val_loss: 6.0631e-04
# Epoch 10/10
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 50s 146ms/step - loss: 0.0012 - val_loss: 6.4229e-04

# %%
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()

# %%
n_past = 168
n_days_for_prediction= 168

# %%
cutoff_date = '2024-10-17 00:00:00'

# %%
predict_period_dates = pd.date_range(cutoff_date, periods=n_days_for_prediction, freq='h').tolist()
print(predict_period_dates)
# Out:
# [Timestamp('2024-10-17 00:00:00'), Timestamp('2024-10-17 01:00:00'), Timestamp('2024-10-17 02:00:00'), Timestamp('2024-10-17 03:00:00'), Timestamp('2024-10-17 04:00:00'), Timestamp('2024-10-17 05:00:00'), Timestamp('2024-10-17 06:00:00'), Timestamp('2024-10-17 07:00:00'), Timestamp('2024-10-17 08:00:00'), Timestamp('2024-10-17 09:00:00'), Timestamp('2024-10-17 10:00:00'), Timestamp('2024-10-17 11:00:00'), Timestamp('2024-10-17 12:00:00'), Timestamp('2024-10-17 13:00:00'), Timestamp('2024-10-17 14:00:00'), Timestamp('2024-10-17 15:00:00'), Timestamp('2024-10-17 16:00:00'), Timestamp('2024-10-17 17:00:00'), Timestamp('2024-10-17 18:00:00'), Timestamp('2024-10-17 19:00:00'), Timestamp('2024-10-17 20:00:00'), Timestamp('2024-10-17 21:00:00'), Timestamp('2024-10-17 22:00:00'), Timestamp('2024-10-17 23:00:00'), Timestamp('2024-10-18 00:00
2024-10-21 09:00:00'), Timestamp('2024-10-21 10:00:00'), Timestamp('2024-10-21 11:00:00'), Timestamp('2024-10-21 12:00:00'), Timestamp('2024-10-21 13:00:00'), Timestamp('2024-10-21 14:00:00'), Timestamp('2024-10-21 15:00:00'), Timestamp('2024-10-21 16:00:00'), Timestamp('2024-10-21 17:00:00'), Timestamp('2024-10-21 18:00:00'), Timestamp('2024-10-21 19:00:00'), Timestamp('2024-10-21 20:00:00'), Timestamp('2024-10-21 ...

# %%
prediction = model.predict(trainX[-n_days_for_prediction:])
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step

# %%
prediction_copies = np.repeat(prediction, df_for_training.shape[1], axis=-1)
y_pred_future = scaler.inverse_transform(prediction_copies)[:,0]

# %%
# Convert timestamp to date
forecast_dates = []
for time_i in predict_period_dates:
    forecast_dates.append(time_i)

# %%
df_forecast = pd.DataFrame({'date':np.array(forecast_dates), 'consumption':y_pred_future})
df_forecast['date']=pd.to_datetime(df_forecast['date'])
df_forecast.head()
# Out:
#                  date  consumption
# 0 2024-10-17 00:00:00  1072.022827
# 1 2024-10-17 01:00:00  1007.844421
# 2 2024-10-17 02:00:00  1001.284607
# 3 2024-10-17 03:00:00  1050.601685
# 4 2024-10-17 04:00:00  1082.216187

# %%
original = pd.read_csv('forecasts/actuals.csv')
original['date'] = original['date'].astype({'date': 'datetime64[ns]'})
# original = original.iloc[:24,:]
original.head()
# Out:
#                  date  consumption
# 0 2024-10-17 00:00:00       1141.0
# 1 2024-10-17 01:00:00       1097.0
# 2 2024-10-17 02:00:00       1062.0
# 3 2024-10-17 03:00:00       1083.0
# 4 2024-10-17 04:00:00       1101.0

# %%
from sklearn.metrics import mean_absolute_error, root_mean_squared_error, mean_absolute_percentage_error # type: ignore
from sktime.performance_metrics.forecasting import mean_squared_percentage_error # type: ignore

mse = root_mean_squared_error(original['consumption'], df_forecast['consumption'])
mae = mean_absolute_error(original['consumption'], df_forecast['consumption'])
mape = mean_absolute_percentage_error(original['consumption'], df_forecast['consumption'])
rmspe = mean_squared_percentage_error(original['consumption'], df_forecast['consumption'], square_root=True)

plt_title = 'MAE: {0:.2f}, RMSE: {1:.2f}, MAPE: {2:.2f}, RMSPE: {3:.2f}'.format(mae, mse, mape*100, rmspe*100)

# %%
plt.plot(original['date'], original['consumption'])
plt.plot(df_forecast['date'], df_forecast['consumption'])
# change axis date format
plt.gcf().autofmt_xdate()
plt.xlabel('Date')
plt.ylabel('Consumption')
plt.title(plt_title)
# set figsize to (19, 6)
plt.gcf().set_size_inches(19, 6)

# %% [markdown]
# 1 <br>
# MAE: 112.01, RMSE: 185.12, MAPE: 9.08, RMSPE: 15.33<br>
# consumption	temperature	precipitation	irradiation	cloudiness	holiday	shifted_consumption_168	shifted_consumption_48	hour	weekDay
#
# 2 <br>
# MAE: 127.40, RMSE: 193.21, MAPE: 10.17, RMSPE: 15.69<br>
# consumption	temperature	precipitation	irradiation	cloudiness	holiday
#
# 3 <br>
# MAE: 112.07, RMSE: 179.88, MAPE: 8.98, RMSPE: 14.47<br>
# consumption	temperature
#
# 4 <br>
# MAE: 108.93, RMSE: 180.17, MAPE: 8.77, RMSPE: 14.49<br>
# consumption	temperature BiGRU

# %%
# df_forecast.to_csv('forecasts/forecast_GRU.csv', index=False)
